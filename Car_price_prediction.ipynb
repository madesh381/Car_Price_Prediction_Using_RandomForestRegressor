# %%
import pandas as pd
import warnings
from sklearn.preprocessing import LabelEncoder
df=pd.read_csv(r'C:\Users\madhe\Downloads\car_sales_data.csv')
df
# Out:
#       Manufacturer       Model  Engine size Fuel type  Year of manufacture  \
# 0             Ford      Fiesta          1.0    Petrol                 2002
# 1          Porsche  718 Cayman          4.0    Petrol                 2016
# 2             Ford      Mondeo          1.6    Diesel                 2014
# 3           Toyota        RAV4          1.8    Hybrid                 1988
# 4               VW        Polo          1.0    Petrol                 2006
# ...            ...         ...          ...       ...                  ...
# 49995          BMW          M5          5.0    Petrol                 2018
# 49996       Toyota       Prius          1.8    Hybrid                 2003
# 49997         Ford      Mondeo          1.6    Diesel                 2022
# 49998         Ford       Focus          1.0    Diesel                 2016
# 49999           VW        Golf          1.4    Diesel                 2012
#
#        Mileage   Price
# 0       127300    3074
# ...

# %%
df.isnull()
# Out:
#        Manufacturer  Model  Engine size  Fuel type  Year of manufacture  \
# 0             False  False        False      False                False
# 1             False  False        False      False                False
# 2             False  False        False      False                False
# 3             False  False        False      False                False
# 4             False  False        False      False                False
# ...             ...    ...          ...        ...                  ...
# 49995         False  False        False      False                False
# 49996         False  False        False      False                False
# 49997         False  False        False      False                False
# 49998         False  False        False      False                False
# 49999         False  False        False      False                False
#
#        Mileage  Price
# 0        False  False
# 1        False  False
# 2        False  False
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Engine size            0
# Fuel type              0
# Year of manufacture    0
# Mileage                0
# Price                  0
# dtype: int64

# %%
df.dropna()
# Out:
#       Manufacturer       Model  Engine size Fuel type  Year of manufacture  \
# 0             Ford      Fiesta          1.0    Petrol                 2002
# 1          Porsche  718 Cayman          4.0    Petrol                 2016
# 2             Ford      Mondeo          1.6    Diesel                 2014
# 3           Toyota        RAV4          1.8    Hybrid                 1988
# 4               VW        Polo          1.0    Petrol                 2006
# ...            ...         ...          ...       ...                  ...
# 49995          BMW          M5          5.0    Petrol                 2018
# 49996       Toyota       Prius          1.8    Hybrid                 2003
# 49997         Ford      Mondeo          1.6    Diesel                 2022
# 49998         Ford       Focus          1.0    Diesel                 2016
# 49999           VW        Golf          1.4    Diesel                 2012
#
#        Mileage   Price
# 0       127300    3074
# ...

# %%
df=df.drop_duplicates()

# %%
df['Model'].unique()
# Out:
# array(['Fiesta', '718 Cayman', 'Mondeo', 'RAV4', 'Polo', 'Focus', 'Prius',
#        'Golf', 'Z4', 'Yaris', '911', 'Passat', 'M5', 'Cayenne', 'X3'],
#       dtype=object)

# %%
df['Fuel type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'Hybrid'], dtype=object)

# %%
df.describe()
# Out:
#         Engine size  Year of manufacture        Mileage          Price
# count  49988.000000         49988.000000   49988.000000   49988.000000
# mean       1.773140          2004.209630  112515.561215   13829.112387
# std        0.734149             9.646056   71624.341062   16417.812203
# min        1.000000          1984.000000     630.000000      76.000000
# 25%        1.400000          1996.000000   54375.250000    3059.750000
# 50%        1.600000          2004.000000  101011.500000    7971.000000
# 75%        2.000000          2012.000000  158617.250000   19028.500000
# max        5.000000          2022.000000  453537.000000  168081.000000

# %%
label_enc_model = LabelEncoder()
label_enc_fuel = LabelEncoder()

# %%
df_label = df.copy()
df_label['Model'] = label_enc_model.fit_transform(df_label['Model'])
df_label['Fuel type'] = label_enc_fuel.fit_transform(df_label['Fuel type'])

# %%
df_label
# Out:
#       Manufacturer  Model  Engine size  Fuel type  Year of manufacture  \
# 0             Ford      3          1.0          2                 2002
# 1          Porsche      0          4.0          2                 2016
# 2             Ford      7          1.6          0                 2014
# 3           Toyota     11          1.8          1                 1988
# 4               VW      9          1.0          2                 2006
# ...            ...    ...          ...        ...                  ...
# 49995          BMW      6          5.0          2                 2018
# 49996       Toyota     10          1.8          1                 2003
# 49997         Ford      7          1.6          0                 2022
# 49998         Ford      4          1.0          0                 2016
# 49999           VW      5          1.4          0                 2012
#
#        Mileage   Price
# 0       127300    3074
# 1        57850   49704
# 2        39190   24072
# ...

# %%
df_label
# Out:
#       Manufacturer  Model  Engine size  Fuel type  Year of manufacture  \
# 0             Ford      3          1.0          2                 2002
# 1          Porsche      0          4.0          2                 2016
# 2             Ford      7          1.6          0                 2014
# 3           Toyota     11          1.8          1                 1988
# 4               VW      9          1.0          2                 2006
# ...            ...    ...          ...        ...                  ...
# 49995          BMW      6          5.0          2                 2018
# 49996       Toyota     10          1.8          1                 2003
# 49997         Ford      7          1.6          0                 2022
# 49998         Ford      4          1.0          0                 2016
# 49999           VW      5          1.4          0                 2012
#
#        Mileage   Price
# 0       127300    3074
# 1        57850   49704
# 2        39190   24072
# ...

# %%
len(df)
# Out:
# 49988

# %%
df_label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49988 entries, 0 to 49999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         49988 non-null  object
#  1   Model                49988 non-null  int64
#  2   Engine size          49988 non-null  float64
#  3   Fuel type            49988 non-null  int64
#  4   Year of manufacture  49988 non-null  int64
#  5   Mileage              49988 non-null  int64
#  6   Price                49988 non-null  int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 3.1+ MB

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df_label.head()
# Out:
#   Manufacturer  Model  Engine size  Fuel type  Year of manufacture  Mileage  \
# 0         Ford      3          1.0          2                 2002   127300
# 1      Porsche      0          4.0          2                 2016    57850
# 2         Ford      7          1.6          0                 2014    39190
# 3       Toyota     11          1.8          1                 1988   210814
# 4           VW      9          1.0          2                 2006   127869
#
#    Price
# 0   3074
# 1  49704
# 2  24072
# 3   1705
# 4   4101

# %%
df1 = df_label.drop(columns=["Manufacturer","Year of manufacture"])
df1
# Out:
#        Model  Engine size  Fuel type  Mileage   Price
# 0          3          1.0          2   127300    3074
# 1          0          4.0          2    57850   49704
# 2          7          1.6          0    39190   24072
# 3         11          1.8          1   210814    1705
# 4          9          1.0          2   127869    4101
# ...      ...          ...        ...      ...     ...
# 49995      6          5.0          2    28664  113006
# 49996     10          1.8          1   105120    9430
# 49997      7          1.6          0     4030   49852
# 49998      4          1.0          0    26468   23630
# 49999      5          1.4          0   109300   10400
#
# [49988 rows x 5 columns]

# %%
x=df1.iloc[:,df1.columns!='Mileage']
y=df1.iloc[:,df1.columns=='Mileage']

# %%
df1.head()
# Out:
#    Model  Engine size  Fuel type  Mileage  Price
# 0      3          1.0          2   127300   3074
# 1      0          4.0          2    57850  49704
# 2      7          1.6          0    39190  24072
# 3     11          1.8          1   210814   1705
# 4      9          1.0          2   127869   4101

# %%
df1.corr()
# Out:
#                 Model  Engine size  Fuel type   Mileage     Price
# Model        1.000000    -0.077380  -0.120376 -0.005604 -0.034286
# Engine size -0.077380     1.000000   0.075790  0.004365  0.398391
# Fuel type   -0.120376     0.075790   1.000000  0.001857  0.007971
# Mileage     -0.005604     0.004365   0.001857  1.000000 -0.632817
# Price       -0.034286     0.398391   0.007971 -0.632817  1.000000

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr_model = LinearRegression()
lr_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr_model.intercept_
# Out:
# array([108650.7760273])

# %%
lr_model.coef_
# Out:
# array([[-2.13443620e+02,  2.98046455e+04, -1.35210622e+03,
#         -3.29748466e+00]])

# %%
dir(lr_model)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__sklearn_tags__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_feature_names',
#  '_check_n_features',
#  '_decision_function',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_get_default_requests',
#  '_get_doc_link',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_parameter_constraints',
# ...

# %%
y_pred = lr_model.predict(x_test)

# %%
train_score=lr_model.score(x_train,y_train)
test_score=lr_model.score(x_test,y_test)

# %%
train_score
# Out:
# 0.47829692378485655

# %%
test_score
# Out:
# 0.48161081896677127

# %%
x_test.shape
# Out:
# (9998, 4)

# %%
y_train.shape
# Out:
# (39990, 1)

# %%
from sklearn.ensemble import RandomForestRegressor
import warnings

# %%
model = RandomForestRegressor(n_estimators=50, random_state=42)
model.fit(x_train, y_train)
# Out:
# C:\Users\madhe\anaconda3\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(n_estimators=50, random_state=42)

# %%
dir(model)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__sklearn_tags__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_build_request_for_signature',
#  '_check_feature_names',
#  '_check_n_features',
#  '_compute_oob_predictions',
#  '_compute_partial_dependence_recursion',
#  '_doc_link_module',
#  '_doc_link_template',
#  '_doc_link_url_param_generator',
#  '_estimator_type',
#  '_get_default_requests',
#  '_get_doc_link',
# ...

# %%
y_pred = model.predict(x_test)

# %%
train_score=model.score(x_train,y_train)
test_score=model.score(x_test,y_test)

# %%
train_score
# Out:
# 0.9817152960813862

# %%
test_score
# Out:
# 0.8784129641780373

# %%
df1
# Out:
#        Model  Engine size  Fuel type  Mileage   Price
# 0          3          1.0          2   127300    3074
# 1          0          4.0          2    57850   49704
# 2          7          1.6          0    39190   24072
# 3         11          1.8          1   210814    1705
# 4          9          1.0          2   127869    4101
# ...      ...          ...        ...      ...     ...
# 49995      6          5.0          2    28664  113006
# 49996     10          1.8          1   105120    9430
# 49997      7          1.6          0     4030   49852
# 49998      4          1.0          0    26468   23630
# 49999      5          1.4          0   109300   10400
#
# [49988 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.barplot(x="Model", y="Price", data=df1)
plt.title("price Predicitions")
plt.xlabel("Model", fontsize=12, color="darkred")
plt.ylabel("Price", fontsize=12, color="darkgreen")
plt.show()
